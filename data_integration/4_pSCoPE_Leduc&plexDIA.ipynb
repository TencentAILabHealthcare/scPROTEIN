# %%
import argparse
import random
import sys

from scprotein import *
import numpy as np 
import scipy.sparse as sp
import os
from batch_visualization import *

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--learning_rate", type=float, default=1e-3, help='Learning rate.')
parser.add_argument("--num_hidden", type=int, default=128, help='Hidden dimension.')
parser.add_argument("--num_proj_hidden", type=int, default=128, help='num_proj_hidden dimension.')
parser.add_argument("--activation", type=str, default='relu', help='activation function')
parser.add_argument("--num_layers", type=int, default=2, help='num layers.')
parser.add_argument("--num_protos", type=int, default=3, help='num of prototypes')
parser.add_argument("--num_changed_edges", type=int, default=50, help='num of added/removed edges')
parser.add_argument("--topology_denoising", type=bool, default=False, help='if scPROTEIN uses topology denoising')
parser.add_argument("--drop_edge_rate_1", type=float, default=0., help='drop_edge_rate_1') 
parser.add_argument("--drop_edge_rate_2", type=float, default=0.1, help='drop_edge_rate_2') 
parser.add_argument("--drop_feature_rate_1", type=float, default=0.1, help='drop_feature_rate_1')  
parser.add_argument("--drop_feature_rate_2", type=float, default=0., help='drop_feature_rate_2') 
parser.add_argument("--threshold", type=float, default=0.055, help='threshold of graph construct') 
parser.add_argument("--tau", type=float, default=0.4, help='tau')
parser.add_argument("--weight_decay", type=float, default=0., help='weight_decay')
parser.add_argument("--num_epochs", type=int, default=200, help='Number of epochs.')
parser.add_argument("--seed", type=int, default=777, help='Random seed.')  
parser.add_argument("--alpha", type=float, default=0.05, help='balance factor')
parser.add_argument("--feature_preprocess", type=bool, default=False, help='feature preprocess')

args =parser.parse_known_args()[0]  
setup_seed(args.seed)
activation = nn.PReLU() if args.activation == 'prelu' else F.relu

# %%
batch_label,cell_type_with_dataname,cell_type_label,overlap_cell_type_label, features = integrate_sc_proteomic_features('pSCoPE_Leduc','plexDIA')
# Out:
# overlap celltype: ['U-937', 'Melanoma']
# overlap protein nums: 1075

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
data = graph_generation(features, args.threshold, args.feature_preprocess).to(device)
torch.cuda.empty_cache()

encoder = Encoder(data.num_features, args.num_hidden, activation, k=args.num_layers).to(device)
model = Model(encoder, args.num_hidden, args.num_proj_hidden, args.tau).to(device)

scPROTEIN = scPROTEIN_learning(model,device, data, args.drop_feature_rate_1,args.drop_feature_rate_2,args.drop_edge_rate_1,args.drop_edge_rate_2,
                 args.learning_rate, args.weight_decay, args.num_protos, args.topology_denoising, args.num_epochs, args.alpha, args.num_changed_edges,args.seed)

# %%
scPROTEIN.train()
# Out:
# (T) | Epoch=001, loss=8.0239
# (T) | Epoch=002, loss=7.5431
# (T) | Epoch=003, loss=7.4190
# (T) | Epoch=004, loss=7.3968
# (T) | Epoch=005, loss=7.3754
# (T) | Epoch=006, loss=7.3656
# (T) | Epoch=007, loss=7.3513
# (T) | Epoch=008, loss=7.3394
# (T) | Epoch=009, loss=7.3241
# (T) | Epoch=010, loss=7.3101
# (T) | Epoch=011, loss=7.2945
# (T) | Epoch=012, loss=7.2765
# (T) | Epoch=013, loss=7.2576
# (T) | Epoch=014, loss=7.2330
# (T) | Epoch=015, loss=7.2012
# (T) | Epoch=016, loss=7.1587
# (T) | Epoch=017, loss=7.0973
# (T) | Epoch=018, loss=7.0208
# (T) | Epoch=019, loss=6.9624
# (T) | Epoch=020, loss=6.8817
# (T) | Epoch=021, loss=7.0055
# (T) | Epoch=022, loss=6.8420
# (T) | Epoch=023, loss=6.8420
# (T) | Epoch=024, loss=6.8141
# (T) | Epoch=025, loss=6.7641
# (T) | Epoch=026, loss=6.7558
# (T) | Epoch=027, loss=6.7465
# (T) | Epoch=028, loss=6.7333
# (T) | Epoch=029, loss=6.7176
# (T) | Epoch=030, loss=6.7027
# (T) | Epoch=031, loss=6.6855
# (T) | Epoch=032, loss=6.6815
# (T) | Epoch=033, loss=6.6627
# (T) | Epoch=034, loss=6.6496
# (T) | Epoch=035, loss=6.6633
# (T) | Epoch=036, loss=6.6541
# (T) | Epoch=037, loss=6.6384
# (T) | Epoch=038, loss=6.6392
# (T) | Epoch=039, loss=6.6436
# (T) | Epoch=040, loss=6.6211
# (T) | Epoch=041, loss=6.6041
# (T) | Epoch=042, loss=6.6106
# (T) | Epoch=043, loss=6.6223
# (T) | Epoch=044, loss=6.6271
# (T) | Epoch=045, loss=6.6068
# (T) | Epoch=046, loss=6.5948
# (T) | Epoch=047, loss=6.5824
# (T) | Epoch=048, loss=6.5779
# (T) | Epoch=049, loss=6.5725
# (T) | Epoch=050, loss=6.5606
# (T) | Epoch=051, loss=6.5579
# (T) | Epoch=052, loss=6.5548
# (T) | Epoch=053, loss=6.5507
# (T) | Epoch=054, loss=6.5371
# (T) | Epoch=055, loss=6.5311
# (T) | Epoch=056, loss=6.5270
# (T) | Epoch=057, loss=6.5079
# (T) | Epoch=058, loss=6.5054
# (T) | Epoch=059, loss=6.5106
# (T) | Epoch=060, loss=6.4965
# (T) | Epoch=061, loss=6.5063
# (T) | Epoch=062, loss=6.4917
# (T) | Epoch=063, loss=6.4851
# (T) | Epoch=064, loss=6.4862
# (T) | Epoch=065, loss=6.4819
# (T) | Epoch=066, loss=6.4878
# (T) | Epoch=067, loss=6.4947
# (T) | Epoch=068, loss=6.4832
# (T) | Epoch=069, loss=6.4711
# (T) | Epoch=070, loss=6.4641
# (T) | Epoch=071, loss=6.4724
# (T) | Epoch=072, loss=6.4615
# (T) | Epoch=073, loss=6.4587
# (T) | Epoch=074, loss=6.4650
# (T) | Epoch=075, loss=6.4497
# (T) | Epoch=076, loss=6.4478
# (T) | Epoch=077, loss=6.4309
# (T) | Epoch=078, loss=6.4413
# (T) | Epoch=079, loss=6.4209
# (T) | Epoch=080, loss=6.4262
# (T) | Epoch=081, loss=6.4188
# (T) | Epoch=082, loss=6.4114
# (T) | Epoch=083, loss=6.4172
# (T) | Epoch=084, loss=6.4040
# (T) | Epoch=085, loss=6.3939
# (T) | Epoch=086, loss=6.3895
# (T) | Epoch=087, loss=6.4024
# (T) | Epoch=088, loss=6.4091
# (T) | Epoch=089, loss=6.3814
# (T) | Epoch=090, loss=6.3895
# (T) | Epoch=091, loss=6.3928
# (T) | Epoch=092, loss=6.3986
# (T) | Epoch=093, loss=6.3874
# (T) | Epoch=094, loss=6.3796
# (T) | Epoch=095, loss=6.3721
# (T) | Epoch=096, loss=6.3760
# (T) | Epoch=097, loss=6.3594
# (T) | Epoch=098, loss=6.3888
# (T) | Epoch=099, loss=6.3615
# (T) | Epoch=100, loss=6.3626
# (T) | Epoch=101, loss=6.3667
# (T) | Epoch=102, loss=6.3463
# (T) | Epoch=103, loss=6.3636
# (T) | Epoch=104, loss=6.3414
# (T) | Epoch=105, loss=6.3635
# (T) | Epoch=106, loss=6.3491
# (T) | Epoch=107, loss=6.3322
# (T) | Epoch=108, loss=6.3462
# (T) | Epoch=109, loss=6.3195
# (T) | Epoch=110, loss=6.3202
# (T) | Epoch=111, loss=6.3234
# (T) | Epoch=112, loss=6.3328
# (T) | Epoch=113, loss=6.3428
# (T) | Epoch=114, loss=6.3356
# (T) | Epoch=115, loss=6.3295
# (T) | Epoch=116, loss=6.3115
# (T) | Epoch=117, loss=6.3176
# (T) | Epoch=118, loss=6.3426
# (T) | Epoch=119, loss=6.3112
# (T) | Epoch=120, loss=6.2932
# (T) | Epoch=121, loss=6.3021
# (T) | Epoch=122, loss=6.3042
# (T) | Epoch=123, loss=6.2974
# (T) | Epoch=124, loss=6.3316
# (T) | Epoch=125, loss=6.2931
# (T) | Epoch=126, loss=6.2937
# (T) | Epoch=127, loss=6.2873
# (T) | Epoch=128, loss=6.2781
# (T) | Epoch=129, loss=6.2743
# (T) | Epoch=130, loss=6.2713
# (T) | Epoch=131, loss=6.2748
# (T) | Epoch=132, loss=6.2679
# (T) | Epoch=133, loss=6.2913
# (T) | Epoch=134, loss=6.2589
# (T) | Epoch=135, loss=6.2666
# (T) | Epoch=136, loss=6.2667
# (T) | Epoch=137, loss=6.2805
# (T) | Epoch=138, loss=6.2590
# (T) | Epoch=139, loss=6.2543
# (T) | Epoch=140, loss=6.2379
# (T) | Epoch=141, loss=6.2587
# (T) | Epoch=142, loss=6.2474
# (T) | Epoch=143, loss=6.2335
# (T) | Epoch=144, loss=6.2384
# (T) | Epoch=145, loss=6.2459
# (T) | Epoch=146, loss=6.2407
# (T) | Epoch=147, loss=6.2442
# (T) | Epoch=148, loss=6.2195
# (T) | Epoch=149, loss=6.2245
# (T) | Epoch=150, loss=6.2338
# (T) | Epoch=151, loss=6.2172
# (T) | Epoch=152, loss=6.2209
# (T) | Epoch=153, loss=6.2108
# (T) | Epoch=154, loss=6.2023
# (T) | Epoch=155, loss=6.2147
# (T) | Epoch=156, loss=6.2054
# (T) | Epoch=157, loss=6.2178
# (T) | Epoch=158, loss=6.2099
# (T) | Epoch=159, loss=6.1916
# (T) | Epoch=160, loss=6.1936
# (T) | Epoch=161, loss=6.2071
# (T) | Epoch=162, loss=6.2082
# (T) | Epoch=163, loss=6.1835
# (T) | Epoch=164, loss=6.2087
# (T) | Epoch=165, loss=6.1913
# (T) | Epoch=166, loss=6.2201
# (T) | Epoch=167, loss=6.1903
# (T) | Epoch=168, loss=6.1992
# (T) | Epoch=169, loss=6.1740
# (T) | Epoch=170, loss=6.1886
# (T) | Epoch=171, loss=6.1648
# (T) | Epoch=172, loss=6.1613
# (T) | Epoch=173, loss=6.1690
# (T) | Epoch=174, loss=6.1522
# (T) | Epoch=175, loss=6.1557
# (T) | Epoch=176, loss=6.1505
# (T) | Epoch=177, loss=6.1570
# (T) | Epoch=178, loss=6.1538
# (T) | Epoch=179, loss=6.1910
# (T) | Epoch=180, loss=6.1551
# (T) | Epoch=181, loss=6.1494
# (T) | Epoch=182, loss=6.1363
# (T) | Epoch=183, loss=6.1575
# (T) | Epoch=184, loss=6.1510
# (T) | Epoch=185, loss=6.1392
# (T) | Epoch=186, loss=6.1427
# (T) | Epoch=187, loss=6.1317
# (T) | Epoch=188, loss=6.1267
# (T) | Epoch=189, loss=6.1339
# (T) | Epoch=190, loss=6.1345
# (T) | Epoch=191, loss=6.1222
# (T) | Epoch=192, loss=6.1371
# (T) | Epoch=193, loss=6.1452
# (T) | Epoch=194, loss=6.1214
# (T) | Epoch=195, loss=6.1227
# (T) | Epoch=196, loss=6.1115
# (T) | Epoch=197, loss=6.1123
# (T) | Epoch=198, loss=6.1212
# (T) | Epoch=199, loss=6.1267
# (T) | Epoch=200, loss=6.1273

# %%
embedding = scPROTEIN.embedding_generation()
np.save('embedding_pscope_leduc_plexDIA.npy',embedding)

# %%
celltype_clus(embedding,cell_type_label)
# Out:
#      ASW    ARI    NMI    PS
# 0  0.475  0.908  0.847  0.96

# %%
batch_clus(embedding,cell_type_label,batch_label,overlap_cell_type_label)
# Out:
#    1-ASW  1-ARI  1-NMI   1-PS
# 0  0.864  1.003  0.947  0.064

# %%
integration_visualization(cell_type_with_dataname,embedding)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
